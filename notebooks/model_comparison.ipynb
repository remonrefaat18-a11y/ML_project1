# %%
import pandas as pd

dt=pd.read_csv("../results/decisiontree_results.csv")
knn=pd.read_csv("../results/KNN_results.csv")
rf=pd.read_csv("../results/randomforest_results.csv")
nb=pd.read_csv("../results/naivebayes_results.csv")


comparison = pd.concat(
    [dt, knn, rf,nb],
    ignore_index=True
)

comparison.set_index("Model").style.background_gradient(cmap="Greens")
# Out:
# <style type="text/css">
# #T_b8da9_row0_col0 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_b8da9_row0_col1 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_b8da9_row0_col2, #T_b8da9_row0_col3, #T_b8da9_row1_col0, #T_b8da9_row1_col4 {
#   background-color: #00481d;
#   color: #f1f1f1;
# }
# #T_b8da9_row0_col4 {
#   background-color: #005321;
#   color: #f1f1f1;
# }
# #T_b8da9_row1_col1 {
#   background-color: #006428;
#   color: #f1f1f1;
# }
# #T_b8da9_row1_col2, #T_b8da9_row1_col3 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_b8da9_row2_col0, #T_b8da9_row2_col1, #T_b8da9_row2_col2, #T_b8da9_row2_col3, #T_b8da9_row2_col4 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_b8da9_row3_col0, #T_b8da9_row3_col1, #T_b8da9_row3_col2, #T_b8da9_row3_col3, #T_b8da9_row3_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_b8da9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8da9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b8da9_level0_col1" class="col_heading level0 col1" >Precision</th>
#       <th id="T_b8da9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b8da9_level0_col3" class="col_heading level0 col3" >F1 Score</th>
#       <th id="T_b8da9_level0_col4" class="col_heading level0 col4" >ROC AUC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8da9_level0_row0" class="row_heading level0 row0" >Decision Tree</th>
#       <td id="T_b8da9_row0_col0" class="data row0 col0" >0.987868</td>
#       <td id="T_b8da9_row0_col1" class="data row0 col1" >0.990958</td>
#       <td id="T_b8da9_row0_col2" class="data row0 col2" >0.992035</td>
#       <td id="T_b8da9_row0_col3" class="data row0 col3" >0.991496</td>
#       <td id="T_b8da9_row0_col4" class="data row0 col4" >0.984715</td>
#     </tr>
#     <tr>
#       <th id="T_b8da9_level0_row1" class="row_heading level0 row1" >KNN</th>
#       <td id="T_b8da9_row1_col0" class="data row1 col0" >0.991224</td>
#       <td id="T_b8da9_row1_col1" class="data row1 col1" >0.993131</td>
#       <td id="T_b8da9_row1_col2" class="data row1 col2" >0.994569</td>
#       <td id="T_b8da9_row1_col3" class="data row1 col3" >0.993849</td>
#       <td id="T_b8da9_row1_col4" class="data row1 col4" >0.995799</td>
#     </tr>
#     <tr>
#       <th id="T_b8da9_level0_row2" class="row_heading level0 row2" >Random Forest</th>
#       <td id="T_b8da9_row2_col0" class="data row2 col0" >0.996902</td>
#       <td id="T_b8da9_row2_col1" class="data row2 col1" >0.996390</td>
#       <td id="T_b8da9_row2_col2" class="data row2 col2" >0.999276</td>
#       <td id="T_b8da9_row2_col3" class="data row2 col3" >0.997831</td>
#       <td id="T_b8da9_row2_col4" class="data row2 col4" >0.999475</td>
#     </tr>
#     <tr>
#       <th id="T_b8da9_level0_row3" class="row_heading level0 row3" >Naive Bayes</th>
#       <td id="T_b8da9_row3_col0" class="data row3 col0" >0.573309</td>
#       <td id="T_b8da9_row3_col1" class="data row3 col1" >0.964017</td>
#       <td id="T_b8da9_row3_col2" class="data row3 col2" >0.417089</td>
#       <td id="T_b8da9_row3_col3" class="data row3 col3" >0.582259</td>
#       <td id="T_b8da9_row3_col4" class="data row3 col4" >0.689210</td>
#     </tr>
#   </tbody>
# </table>

# %%
import matplotlib.pyplot as plt

comparison.plot(
    x="Model",
    y=["Accuracy", "Precision", "Recall", "F1 Score", "ROC AUC"],
    kind="bar",
    figsize=(10,6)
)

plt.title("Models Comparison")
plt.ylabel("Score")
plt.xticks(rotation=0)
plt.show()

# %%
ax = comparison.plot(
    x="Model",
    y="Accuracy",
    kind="bar",
    figsize=(8,6)
)

plt.ylim(0.5,1)

for container in ax.containers:
    ax.bar_label(container, fmt="%.4f")

plt.show()

# %%
ax2 = comparison.plot(
    x="Model",
    y="ROC AUC",
    kind="bar",
    figsize=(8,6)
)

plt.ylim(0.5,1)

for container in ax.containers:
    ax.bar_label(container, fmt="%.4f")

plt.show()

# %%
rf_report = pd.read_csv(
    "../results/randomforest_classification_report.csv",
    index_col=0
)

knn_report = pd.read_csv(
    "../results/KNN_classification_report.csv",
    index_col=0
)

dt_report = pd.read_csv(
    "../results/decisiontree_classification_report.csv",
    index_col=0
)

nb_report = pd.read_csv(
    "../results/naivebayes_classification_report.csv",
    index_col=0
)

# %%
print("="*70)
print("Decision Tree")
display(dt_report)

print("="*70)
print("KNN")
display(knn_report)

print("="*70)
print("Random Forest")
display(rf_report)


print("="*70)
print("Naive Bayes")
display(nb_report)
# Out:
# ======================================================================
# Decision Tree
#               precision    recall  f1-score      support
# 0              0.980162  0.977518  0.978838  1112.000000
# 1              0.990958  0.992035  0.991496  2762.000000
# accuracy       0.987868  0.987868  0.987868     0.987868
# macro avg      0.985560  0.984776  0.985167  3874.000000
# weighted avg   0.987859  0.987868  0.987863  3874.000000
# ======================================================================
# KNN
#               precision    recall  f1-score      support
# 0              0.986462  0.982914  0.984685  1112.000000
# 1              0.993131  0.994569  0.993849  2762.000000
# accuracy       0.991224  0.991224  0.991224     0.991224
# macro avg      0.989796  0.988741  0.989267  3874.000000
# weighted avg   0.991217  0.991224  0.991219  3874.000000
# ======================================================================
# Random Forest
#               precision    recall  f1-score      support
# 0              0.998188  0.991007  0.994585  1112.000000
# 1              0.996390  0.999276  0.997831  2762.000000
# accuracy       0.996902  0.996902  0.996902     0.996902
# macro avg      0.997289  0.995142  0.996208  3874.000000
# weighted avg   0.996906  0.996902  0.996899  3874.000000
# ======================================================================
# Naive Bayes
#               precision    recall  f1-score      support
# 0              0.399029  0.961331  0.563967  1112.000000
# 1              0.964017  0.417089  0.582259  2762.000000
# accuracy       0.573309  0.573309  0.573309     0.573309
# macro avg      0.681523  0.689210  0.573113  3874.000000
# weighted avg   0.801842  0.573309  0.577009  3874.000000
